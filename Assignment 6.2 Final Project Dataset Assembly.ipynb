# %% [markdown]
# ## Assignment 6.2
# # Final Project Dataset Assembly
#
# This notebook assembles and cleans movie review data from The Movie Database (TMDB) API. It retrieves movie IDs and reviews across multiple years, filters the data for quality,and prepares a final cleaned dataset suitable for sentiment analysis or predictive modeling.

# %% [markdown]
# Step 1: Importing Libraries

# %%
import warnings
warnings.filterwarnings("ignore")  # hides version-related warnings

import pandas as pd
import requests, json, time, re
from langdetect import detect
import nltk
from nltk.corpus import stopwords

# Download stopwords quietly (no output)
nltk.download("stopwords", quiet=True)

print("✅ All libraries loaded successfully and environment is clean.")
# Out:
# ✅ All libraries loaded successfully and environment is clean.

# %% [markdown]
#  Step 2: TMDB API Setup
#
# In this step, we connect to The Movie Database (TMDB) API, which provides structured access to
# movie information and user reviews. We'll use two API endpoints:
# - `/discover/movie` – to list movies by release year
# - `/movie/{id}/reviews` – to retrieve detailed audience reviews
#
# A valid API token is required for authentication.

# %%
API_URL = "https://api.themoviedb.org/3"
HEADERS = {
    "accept": "application/json",
    "Authorization": "Bearer YOUR_TMDB_API_KEY"  # 🔑 Replace with your TMDB API token
}

print("✅ TMDB API configured successfully.")
# Out:
# ✅ TMDB API configured successfully.

# %% [markdown]
# Step 3: Fetching Movie Metadata
#
# Retrieves movie IDs, titles, and release years via TMDB’s /discover/movie endpoint using a v3 API key, limiting to two pages per year with a 0.05-second delay.

# %%
import time, json, requests

# ✅ Use the short API Key (v3 auth) instead of the long Bearer token
API_KEY = "356e6d6154811b6a3b8400b63c010eaf"  # your v3 key
API_URL = "https://api.themoviedb.org/3"

def get_movies(years):
    movies = []
    for year in years:
        page, total_pages = 1, 1
        max_pages = 2  # limit for speed: 1–2 pages per year
        while page <= min(total_pages, max_pages):
            url = f"{API_URL}/discover/movie?primary_release_year={year}&sort_by=vote_count.desc&page={page}&api_key={API_KEY}"
            try:
                res = requests.get(url, timeout=5)
                print(f"Fetching year {year}, page {page} - status: {res.status_code}")
                res.raise_for_status()
                data = res.json()
            except requests.exceptions.RequestException as e:
                print(f"⚠️ Error fetching {year}, page {page}: {e}")
                break

            total_pages = data.get("total_pages", 1)
            for m in data.get("results", []):
                movies.append({
                    "movie_id": m.get("id"),
                    "title": m.get("original_title"),
                    "year": year
                })

            page += 1
            time.sleep(0.05)  # polite delay
    print(f"\n✅ Collected {len(movies)} movies across {len(years)} years (up to {max_pages} pages each).")
    return movies

# ✅ Example run
years = range(2018, 2022)
movies = get_movies(years)
# Out:
# Fetching year 2018, page 1 - status: 200
# Fetching year 2018, page 2 - status: 200
# Fetching year 2019, page 1 - status: 200
# Fetching year 2019, page 2 - status: 200
# Fetching year 2020, page 1 - status: 200
# Fetching year 2020, page 2 - status: 200
# Fetching year 2021, page 1 - status: 200
# Fetching year 2021, page 2 - status: 200
#
# ✅ Collected 160 movies across 4 years (up to 2 pages each).

# %% [markdown]
#  Step 4: Retrieving Movie Reviews
#
# Once movie IDs are collected, the next step is to fetch their user reviews
# via the `/movie/{id}/reviews` endpoint.
# The function below collects up to five pages of reviews per movie
# to stay within TMDB’s API request limits.

# %%
def get_reviews(movie_id, title):
    reviews, page = [], 1
    while page <= 5:  # limit to 5 pages per movie
        url = f"{API_URL}/movie/{movie_id}/reviews?page={page}&api_key={API_KEY}"
        try:
            res = requests.get(url, timeout=5)
            print(f"Fetching reviews for {title} - page {page} (status: {res.status_code})")
            res.raise_for_status()
            data = res.json()
        except requests.exceptions.RequestException as e:
            print(f"⚠️ Error fetching reviews for {title}, page {page}: {e}")
            break

        for r in data.get("results", []):
            reviews.append({
                "movie_id": movie_id,
                "title": title,
                "review": r.get("content"),
                "rating": r.get("author_details", {}).get("rating")
            })

        if page >= data.get("total_pages", 1):
            break
        page += 1
        time.sleep(0.05)  # short polite delay
    return reviews

# ✅ Example run: fetch reviews for first 3 movies
sample_movies = movies[:3]
all_reviews = []
for m in sample_movies:
    movie_reviews = get_reviews(m["movie_id"], m["title"])
    all_reviews.extend(movie_reviews)

print(f"\n✅ Collected {len(all_reviews)} total reviews for {len(sample_movies)} movies.")
# Out:
# Fetching reviews for Avengers: Infinity War - page 1 (status: 200)
# Fetching reviews for Avengers: Infinity War - page 2 (status: 200)
# Fetching reviews for Black Panther - page 1 (status: 200)
# Fetching reviews for Black Panther - page 2 (status: 200)
# Fetching reviews for Deadpool 2 - page 1 (status: 200)
#
# ✅ Collected 62 total reviews for 3 movies.

# %% [markdown]
# Step 5: Assembling the Raw Dataset
#
# This function merges all movie reviews from multiple years into a single DataFrame.
# It removes rows with missing ratings and exports the raw dataset as a CSV file.
# This dataset will later be cleaned and normalized for analysis.

# %%
import pandas as pd

def assemble_raw_dataset(years):
    all_reviews = []
    movie_list = get_movies(years)  # uses your Step 3 function
    print(f"\n🎬 Fetching reviews for {len(movie_list)} movies...")

    for movie in movie_list:
        movie_reviews = get_reviews(movie["movie_id"], movie["title"])  # Step 4 function
        all_reviews.extend(movie_reviews)
        time.sleep(0.05)  # consistent short delay between movies

    # Convert to DataFrame
    df = pd.DataFrame(all_reviews)

    # Drop missing ratings and select key columns
    df = df.dropna(subset=["rating"], axis=0)
    df = df[["title", "review", "rating"]]

    # Export to CSV
    df.to_csv("tmdb_reviews_raw.csv", index=False)
    print("✅ Raw dataset saved as 'tmdb_reviews_raw.csv'")
    print(f"📊 Final dataset shape: {df.shape}")

    return df

# ✅ Example run
YEARS = range(2018, 2022)
raw_df = assemble_raw_dataset(YEARS)
raw_df.head()
# Out:
# Fetching year 2018, page 1 - status: 200
# Fetching year 2018, page 2 - status: 200
# Fetching year 2019, page 1 - status: 200
# Fetching year 2019, page 2 - status: 200
# Fetching year 2020, page 1 - status: 200
# Fetching year 2020, page 2 - status: 200
# Fetching year 2021, page 1 - status: 200
# Fetching year 2021, page 2 - status: 200
#
# ✅ Collected 160 movies across 4 years (up to 2 pages each).
#
# 🎬 Fetching reviews for 160 movies...
# Fetching reviews for Avengers: Infinity War - page 1 (status: 200)
# Fetching reviews for Avengers: Infinity War - page 2 (status: 200)
# Fetching reviews for Black Panther - page 1 (status: 200)
# Fetching reviews for Black Panther - page 2 (status: 200)
# Fetching reviews for Deadpool 2 - page 1 (status: 200)
# Fetching reviews for Bohemian Rhapsody - page 1 (status: 200)
# Fetching reviews for Venom - page 1 (status: 200)
# Fetching reviews for Spider-Man: Into the Spider-Verse - page 1 (status: 200)
# Fetching reviews for Spider-Man: Into the Spider-Verse - page 2 (status: 200)
# Fetching reviews for Spider-Man: Into the Spider-Verse - page 3 (status: 200)
# Fetching reviews for Ready Player One - page 1 (status: 200)
# Fetching reviews for A Quiet Place - page 1 (status: 200)
# Fetching reviews for Aquaman - page 1 (status: 200)
# Fetching reviews for Ant-Man and the Wasp - page 1 (status: 200)
# Fetching reviews for Incredibles 2 - page 1 (status: 200)
# Fetching reviews for Jurassic World: Fallen Kingdom - page 1 (status: 200)
# Fetching reviews for Green Book - page 1 (status: 200)
# Fetching reviews for A Star Is Born - page 1 (status: 200)
# Fetching reviews for Fantastic Beasts: The Crimes of Grindelwald - page 1 (status: 200)
# Fetching reviews for Bird Box - page 1 (status: 200)
# Fetching reviews for Annihilation - page 1 (status: 200)
# Fetching reviews for Solo: A Star Wars Story - page 1 (status: 200)
# Fetching reviews for Mission: Impossible - Fallout - page 1 (status: 200)
# Fetching reviews for To All the Boys I've Loved Before - page 1 (status: 200)
# Fetching reviews for Ocean's Eight - page 1 (status: 200)
# Fetching reviews for Fifty Shades Freed - page 1 (status: 200)
# Fetching reviews for Hereditary - page 1 (status: 200)
# Fetching reviews for Maze Runner: The Death Cure - page 1 (status: 200)
# Fetching reviews for Tomb Raider - page 1 (status: 200)
# Fetching reviews for The Meg - page 1 (status: 200)
# Fetching reviews for Ralph Breaks the Internet - page 1 (status: 200)
# Fetching reviews for BlacKkKlansman - page 1 (status: 200)
# Fetching reviews for The Kissing Booth - page 1 (status: 200)
# Fetching reviews for Rampage - page 1 (status: 200)
# Fetching reviews for The Nun - page 1 (status: 200)
# Fetching reviews for Bumblebee - page 1 (status: 200)
# Fetching reviews for Red Sparrow - page 1 (status: 200)
# Fetching reviews for Love, Simon - page 1 (status: 200)
# Fetching reviews for Game Night - page 1 (status: 200)
# Fetching reviews for The Favourite - page 1 (status: 200)
# Fetching reviews for The Equalizer 2 - page 1 (status: 200)
# Fetching reviews for Creed II - page 1 (status: 200)
# Fetching reviews for First Man - page 1 (status: 200)
# Fetching reviews for The Mule - page 1 (status: 200)
# Fetching reviews for Joker - page 1 (status: 200)
# Fetching reviews for Avengers: Endgame - page 1 (status: 200)
# Fetching reviews for Avengers: Endgame - page 2 (status: 200)
# Fetching reviews for Avengers: Endgame - page 3 (status: 200)
# Fetching reviews for 기생충 - page 1 (status: 200)
# Fetching reviews for Spider-Man: Far From Home - page 1 (status: 200)
# Fetching reviews for Captain Marvel - page 1 (status: 200)
# Fetching reviews for Once Upon a Time... in Hollywood - page 1 (status: 200)
# Fetching reviews for Knives Out - page 1 (status: 200)
# Fetching reviews for 1917 - page 1 (status: 200)
# Fetching reviews for John Wick: Chapter 3 - Parabellum - page 1 (status: 200)
# Fetching reviews for The Lion King - page 1 (status: 200)
# Fetching reviews for Star Wars: The Rise of Skywalker - page 1 (status: 200)
# Fetching reviews for Aladdin - page 1 (status: 200)
# Fetching reviews for Toy Story 4 - page 1 (status: 200)
# Fetching reviews for Frozen II - page 1 (status: 200)
# Fetching reviews for Jojo Rabbit - page 1 (status: 200)
# Fetching reviews for Shazam! - page 1 (status: 200)
# Fetching reviews for Alita: Battle Angel - page 1 (status: 200)
# Fetching reviews for It Chapter Two - page 1 (status: 200)
# Fetching reviews for Jumanji: The Next Level - page 1 (status: 200)
# Fetching reviews for Glass - page 1 (status: 200)
# Fetching reviews for Ford v Ferrari - page 1 (status: 200)
# Fetching reviews for After - page 1 (status: 200)
# Fetching reviews for Us - page 1 (status: 200)
# Fetching reviews for Midsommar - page 1 (status: 200)
# Fetching reviews for El hoyo - page 1 (status: 200)
# Fetching reviews for Fast & Furious Presents: Hobbs & Shaw - page 1 (status: 200)
# Fetching reviews for The Irishman - page 1 (status: 200)
# Fetching reviews for Marriage Story - page 1 (status: 200)
# Fetching reviews for Pokémon Detective Pikachu - page 1 (status: 200)
# Fetching reviews for Ad Astra - page 1 (status: 200)
# Fetching reviews for How to Train Your Dragon: The Hidden World - page 1 (status: 200)
# Fetching reviews for Dark Phoenix - page 1 (status: 200)
# Fetching reviews for Little Women - page 1 (status: 200)
# Fetching reviews for Godzilla: King of the Monsters - page 1 (status: 200)
# Fetching reviews for Maleficent: Mistress of Evil - page 1 (status: 200)
# Fetching reviews for Zombieland: Double Tap - page 1 (status: 200)
# Fetching reviews for Five Feet Apart - page 1 (status: 200)
# Fetching reviews for Terminator: Dark Fate - page 1 (status: 200)
# Fetching reviews for Gemini Man - page 1 (status: 200)
# Fetching reviews for The Lighthouse - page 1 (status: 200)
# Fetching reviews for Soul - page 1 (status: 200)
# Fetching reviews for Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn) - page 1 (status: 200)
# Fetching reviews for Tenet - page 1 (status: 200)
# Fetching reviews for Sonic the Hedgehog - page 1 (status: 200)
# Fetching reviews for 365 dni - page 1 (status: 200)
# Fetching reviews for Wonder Woman 1984 - page 1 (status: 200)
# Fetching reviews for Bad Boys for Life - page 1 (status: 200)
# Fetching reviews for Mulan - page 1 (status: 200)
# Fetching reviews for Onward - page 1 (status: 200)
# Fetching reviews for Extraction - page 1 (status: 200)
# Fetching reviews for Enola Holmes - page 1 (status: 200)
# Fetching reviews for The Gentlemen - page 1 (status: 200)
# Fetching reviews for The Invisible Man - page 1 (status: 200)
# Fetching reviews for After We Collided - page 1 (status: 200)
# Fetching reviews for Bloodshot - page 1 (status: 200)
# Fetching reviews for The Kissing Booth 2 - page 1 (status: 200)
# Fetching reviews for Greenland - page 1 (status: 200)
# Fetching reviews for The Old Guard - page 1 (status: 200)
# Fetching reviews for 劇場版「鬼滅の刃」無限列車編 - page 1 (status: 200)
# Fetching reviews for Love and Monsters - page 1 (status: 200)
# Fetching reviews for The Croods: A New Age - page 1 (status: 200)
# Fetching reviews for The Call of the Wild - page 1 (status: 200)
# Fetching reviews for Dolittle - page 1 (status: 200)
# Fetching reviews for The New Mutants - page 1 (status: 200)
# Fetching reviews for Druk - page 1 (status: 200)
# Fetching reviews for The Devil All the Time - page 1 (status: 200)
# Fetching reviews for Promising Young Woman - page 1 (status: 200)
# Fetching reviews for The Hunt - page 1 (status: 200)
# Fetching reviews for Monster Hunter - page 1 (status: 200)
# Fetching reviews for The Father - page 1 (status: 200)
# Fetching reviews for Palm Springs - page 1 (status: 200)
# Fetching reviews for Underwater - page 1 (status: 200)
# Fetching reviews for The Trial of the Chicago 7 - page 1 (status: 200)
# Fetching reviews for Greyhound - page 1 (status: 200)
# Fetching reviews for Project Power - page 1 (status: 200)
# Fetching reviews for All the Bright Places - page 1 (status: 200)
# Fetching reviews for The SpongeBob Movie: Sponge on the Run - page 1 (status: 200)
# Fetching reviews for Roald Dahl's The Witches - page 1 (status: 200)
# Fetching reviews for Run - page 1 (status: 200)
# Fetching reviews for Borat Subsequent Moviefilm - page 1 (status: 200)
# Fetching reviews for Spider-Man: No Way Home - page 1 (status: 200)
# Fetching reviews for Dune - page 1 (status: 200)
# Fetching reviews for Venom: Let There Be Carnage - page 1 (status: 200)
# Fetching reviews for Black Widow - page 1 (status: 200)
# Fetching reviews for Zack Snyder's Justice League - page 1 (status: 200)
# Fetching reviews for Godzilla vs. Kong - page 1 (status: 200)
# Fetching reviews for Shang-Chi and the Legend of the Ten Rings - page 1 (status: 200)
# Fetching reviews for Encanto - page 1 (status: 200)
# Fetching reviews for Cruella - page 1 (status: 200)
# Fetching reviews for Free Guy - page 1 (status: 200)
# Fetching reviews for The Suicide Squad - page 1 (status: 200)
# Fetching reviews for Don't Look Up - page 1 (status: 200)
# Fetching reviews for Eternals - page 1 (status: 200)
# Fetching reviews for Luca - page 1 (status: 200)
# Fetching reviews for Nobody - page 1 (status: 200)
# Fetching reviews for F9 - page 1 (status: 200)
# Fetching reviews for Raya and the Last Dragon - page 1 (status: 200)
# Fetching reviews for A Quiet Place Part II - page 1 (status: 200)
# Fetching reviews for No Time to Die - page 1 (status: 200)
# Fetching reviews for The Conjuring: The Devil Made Me Do It - page 1 (status: 200)
# Fetching reviews for The Matrix Resurrections - page 1 (status: 200)
# Fetching reviews for Red Notice - page 1 (status: 200)
# Fetching reviews for Mortal Kombat - page 1 (status: 200)
# Fetching reviews for Jungle Cruise - page 1 (status: 200)
# Fetching reviews for Wrath of Man - page 1 (status: 200)
# Fetching reviews for Ghostbusters: Afterlife - page 1 (status: 200)
# Fetching reviews for The King's Man - page 1 (status: 200)
# Fetching reviews for Old - page 1 (status: 200)
# Fetching reviews for Sing 2 - page 1 (status: 200)
# Fetching reviews for Army of the Dead - page 1 (status: 200)
# Fetching reviews for Space Jam: A New Legacy - page 1 (status: 200)
# Fetching reviews for The Tomorrow War - page 1 (status: 200)
# Fetching reviews for Finch - page 1 (status: 200)
# Fetching reviews for Last Night in Soho - page 1 (status: 200)
# Fetching reviews for The Last Duel - page 1 (status: 200)
# Fetching reviews for House of Gucci - page 1 (status: 200)
# Fetching reviews for Nomadland - page 1 (status: 200)
# Fetching reviews for The Mitchells vs. the Machines - page 1 (status: 200)
# Fetching reviews for Nightmare Alley - page 1 (status: 200)
# Fetching reviews for The Guilty - page 1 (status: 200)
# ✅ Raw dataset saved as 'tmdb_reviews_raw.csv'
# 📊 Final dataset shape: (1111, 3)
#                     title                                             review  \
# 1  Avengers: Infinity War  Amazing.  Visually stunning.  So much going on...
# 2  Avengers: Infinity War  Just a very short, NO SPOILERS review I wanted...
# 3  Avengers: Infinity War  The third act turns on a character being an id...
# 4  Avengers: Infinity War  Best MCU movie, more than that.... BEST SUPERH...
# 6  Avengers: Infinity War  Massive, epic movie. I'm so happy that Marvel ...
#
#    rating
# 1    10.0
# 2     8.0
# 3     4.0
# 4     9.5
# 6     8.0
